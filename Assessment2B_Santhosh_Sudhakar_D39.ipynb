# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv('college_1.csv')
df2=pd.read_csv('college_2.csv')
df=pd.concat([df1,df2])
df.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
# 3  Computer Science and Engineering       0        NaN                     NaN
# 4  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Exceeded_expectations=df[df['CodeKata Score']>15000]
Exceeded_expectations.to_csv('Exceeded_expectations.csv')

# %%
df3=df[df['CodeKata Score']<15000]
Reached_expectations=df3[df3['CodeKata Score']>10000]
Reached_expectations.to_csv('Reached_expectations.csv')

# %%
df4=df[df['CodeKata Score']<10000]
Needs_improvement=df4[df4['CodeKata Score']>7000]
Needs_improvement.to_csv('Needs_improvement.csv')

# %%
Unsatisfactory=df[df['CodeKata Score']<7000]
Unsatisfactory.to_csv('Unsatisfactory.csv')
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
#
#                                    Department  Rising  python_en  \
# 8   Electronics and Communication Engineering       0        NaN
# 9            Computer Science and Engineering       0        NaN
# 10  Electronics and Communication Engineering       0        NaN
# 11           Computer Science and Engineering       0        NaN
# 12           Computer Science and Engineering       0        NaN
#
#     computational_thinking
# 8                      NaN
# 9                      NaN
# 10                     NaN
# 11                     NaN
# ...

# %% [markdown]
# Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %% [markdown]
# ###### No of students participated

# %%
df['Name'].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df['python'].mean()
# Out:
# 54.35294117647059

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.sort_values(by=['Rising'],ascending=False).head(3)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
# 2         Computer Science and Engineering    2000       55.0
#
#     computational_thinking
# 8                      0.0
# 18                     0.0
# 2                      6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.sort_values(by=['Previous Geekions'],ascending=False).head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df.groupby(['Department']).sum().plot(
    kind='pie', y='CodeKata Score',autopct='%1.0f%%',figsize=(15,8))
# Out:
# <AxesSubplot:ylabel='CodeKata Score'>

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
computer=df[df['Department']=='Computer Science and Engineering']
computer.sort_values(by=['CodeKata Score'],ascending=False)
computer.groupby(['Name']).sum().plot(
    kind='bar', y='CodeKata Score',figsize=(15,8))
plt.title('COMPUTER SCIENCE ENGINEERING')
# Out:
# Text(0.5, 1.0, 'COMPUTER SCIENCE ENGINEERING')

# %%
EEE=df[df['Department']=='Electronics and Electrical Engineering']
EEE.sort_values(by=['CodeKata Score'],ascending=False)
EEE.groupby(['Name']).sum().plot(
    kind='bar', y='CodeKata Score',figsize=(15,8))
plt.title('Electronics and Electrical Engineering')
# Out:
# Text(0.5, 1.0, 'Electronics and Electrical Engineering')

# %%
ECE=df[df['Department']=='Electronics and Communication Engineering']
ECE.sort_values(by=['CodeKata Score'],ascending=False)
ECE.groupby(['Name']).sum().plot(
    kind='bar', y='CodeKata Score',figsize=(15,8))
plt.title('Electronics and Communication Engineering')
# Out:
# Text(0.5, 1.0, 'Electronics and Communication Engineering')
